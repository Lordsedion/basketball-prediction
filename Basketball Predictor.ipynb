# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import pandas as pd
import numpy as np
from selenium.webdriver.common.by import By
from time import sleep

# %%
url = 'https://www.flashscore.com.ng/team/philadelphia-76ers/vwRW2QSh/results/'

# %%
driver = webdriver.Chrome(executable_path = r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")
driver.get(url)
ID = 'id'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10484\1042512180.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %% [raw]
# gamed = driver.find_elements(By.CLASS_NAME, 'ui-table__row')
# teambase = []
#
# for game in gamed:
#     try:
#         home_team = game.find_element(By.CLASS_NAME, 'tableCellParticipant__name').text
#     except:
#         continue
#
#     event_item = {
#         'home_team': home_team,
#     }
#
#     teambase.append(event_item)
#
# dt = pd.DataFrame(teambase)

# %%
games = driver.find_elements(By.CLASS_NAME, 'event__match--twoLine')
gamesbase = []

counter = 0
for game in games:
    try:
        home_team = game.find_element(By.CLASS_NAME, 'event__participant--home').text
        away_team = game.find_element(By.CLASS_NAME, 'event__participant--away').text    

        first_quarter_home = game.find_element("xpath", './/*[@class="event__part event__part--home event__part--1"]').text
        second_quarter_home = game.find_element("xpath", './/*[@class="event__part event__part--home event__part--2"]').text
        third_quarter_home = game.find_element("xpath", './/*[@class="event__part event__part--home event__part--3"]').text
        fourth_quarter_home = game.find_element("xpath", './/*[@class="event__part event__part--home event__part--4"]').text
        first_quarter_away = game.find_element("xpath", './/*[@class="event__part event__part--away event__part--1"]').text
        second_quarter_away = game.find_element("xpath", './/*[@class="event__part event__part--away event__part--2"]').text
        third_quarter_away = game.find_element("xpath", './/*[@class="event__part event__part--away event__part--3"]').text
        fourth_quarter_away = game.find_element("xpath", './/*[@class="event__part event__part--away event__part--4"]').text

        event_time = game.find_element("xpath", './/*[@class="event__time"]').text
    except:
        continue
    
    event_item = {
        'home_team': home_team,
        'away_team': away_team,
        'first_quarter_home': first_quarter_home,
        'second_quarter_home': second_quarter_home,
        'third_quarter_home': third_quarter_home,
        'fourth_quarter_home': fourth_quarter_home,
        'first_quarter_away': first_quarter_away,
        'second_quarter_away': second_quarter_away,
        'third_quarter_away': third_quarter_away,
        'fourth_quarter_away': fourth_quarter_away,
        'event_time': event_time,
    }
    counter +=1
    gamesbase.append(event_item)
    
    if counter%50 == 0:
        print(f"{counter} out of {len(games)}      {counter/len(games)*100} % completed")

df = pd.DataFrame(gamesbase)
# Out:
# 50 out of 800      6.25 % completed
# 100 out of 800      12.5 % completed
# 150 out of 800      18.75 % completed
# 200 out of 800      25.0 % completed
# 250 out of 800      31.25 % completed
# 300 out of 800      37.5 % completed
# 350 out of 800      43.75 % completed
# 400 out of 800      50.0 % completed
# 450 out of 800      56.25 % completed
# 500 out of 800      62.5 % completed
# 550 out of 800      68.75 % completed
# 600 out of 800      75.0 % completed
# 650 out of 800      81.25 % completed
# 700 out of 800      87.5 % completed
# 750 out of 800      93.75 % completed
# 800 out of 800      100.0 % completed

# %%
df
# Out:
#                  home_team           away_team first_quarter_home  \
# 0       Philadelphia 76ers       Brooklyn Nets                 30
# 1            Brooklyn Nets  Philadelphia 76ers                 21
# 2            Atlanta Hawks  Philadelphia 76ers                 31
# 3       Philadelphia 76ers          Miami Heat                 31
# 4       Philadelphia 76ers      Boston Celtics                 28
# ..                     ...                 ...                ...
# 795     Philadelphia 76ers       Chicago Bulls                 22
# 796     Philadelphia 76ers       Atlanta Hawks                 20
# 797     Philadelphia 76ers           Utah Jazz                 24
# 798  Oklahoma City Thunder  Philadelphia 76ers                 37
# 799     Philadelphia 76ers     Toronto Raptors                 22
#
#     second_quarter_home third_quarter_home fourth_quarter_home  \
# 0                    37                 26                  28
# ...

# %%
df.to_csv('philadelphia1.csv')

# %%
dt['ratings'] = 8

# %%
rem = 9.5
for i in range(len(dt['home_team'])):
    dt['ratings'][i] = rem
    rem -= 0.5

# %%
dt

# %%
dt.to_csv('euroleague_ratings.csv')
